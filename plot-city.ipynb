# %%
import numpy as np
import matplotlib.pyplot as plt

# this sets up the Matplotlib interactive windows:
# %matplotlib widget

# %% [markdown]
# GPU-driven Pipeline City场景 普通视角

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.

gpu_data = [176, 176, 176, 178, 176, 178, 175, 178, 176, 176, 176, 176, 177, 177, 177, 177, 176, 177, 176, 176, 177, 175, 178, 176, 176, 176, 176, 176, 176, 177, 177, 176, 177, 176, 177, 176, 177, 176, 177, 176, 176, 176, 176, 177, 176, 176, 177, 176, 177, 176, 177, 176, 177, 177, 176, 177, 176, 175, 176, 176]
ax.plot(gpu_data,'-', label='GPU-driven Pipeline', marker = '.',markersize = 8)

deferred_data = [19, 18, 18, 19, 19, 18, 18, 18, 18, 19, 18, 18, 18, 19, 18, 19, 18, 19, 18, 19, 18, 18, 18, 18, 19, 18, 18, 19, 18, 19, 18, 19, 18, 19, 18, 19, 18, 18, 18, 18, 18, 19, 18, 18, 19, 18, 18, 18, 19, 18, 18, 18, 18, 18, 19, 18, 18, 18, 18, 18]
ax.plot(deferred_data, '-', label='Deferred Pipeline', marker = '.',markersize = 8)
ax.set_ylim(bottom=0.0, top=400.0)

ax.legend()

plt.xlabel("time(ms)")  # add X-axis label 
plt.ylabel("frame rate(fps)")  # add Y-axis label 
#plt.fill_between(x, gpu_data, deferred_data, color='green', alpha=0.5) 
plt.grid(axis='y')
plt.show()
plt.savefig("performance-city-common.pdf")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# GPU-driven Pipeline City场景 遮挡视角

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.

x = np.arange(0, 60, 1)
gpu_data = [238, 239, 237, 238, 240, 240, 238, 240, 238, 239, 237, 240, 240, 240, 239, 238, 239, 237, 238, 239, 237, 240, 238, 238, 238, 238, 240, 239, 239, 240, 238, 239, 237, 239, 240, 240, 238, 239, 237, 238, 238, 238, 238, 239, 240, 239, 239, 239, 241, 239, 239, 239, 238, 240, 238, 238, 238, 239, 237, 239]
ax.plot(gpu_data,'-', label='GPU-driven Pipeline', marker = '.',markersize = 8)

deferred_data = [18, 19, 18, 18, 19, 19, 18, 19, 19, 18, 18, 18, 19, 18, 18, 18, 18, 18, 18, 19, 18, 19, 18, 18, 19, 19, 18, 19, 19, 18, 19, 18, 19, 18, 19, 18, 18, 19, 18, 19, 19, 18, 19, 18, 19, 18, 19, 18, 18, 19, 18, 17, 18, 18, 19, 18, 18, 18, 18, 18]
ax.plot(deferred_data, '-', label='Deferred Pipeline', marker = '.',markersize = 8)
ax.set_ylim(bottom=0., top=400.0)

ax.legend()

plt.xlabel("time(ms)")  # add X-axis label 
plt.ylabel("frame rate(fps)")  # add Y-axis label 
#plt.fill_between(x, gpu_data, deferred_data, color='green', alpha=0.5) 
plt.grid(axis='y')
plt.show()
plt.savefig("performance-city-occluded.pdf")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# GPU-driven Pipeline City场景 视锥视角

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.

x = np.arange(0, 60, 1)
gpu_data = [355, 353, 349, 355, 356, 348, 352, 354, 350, 348, 357, 358, 360, 357, 349, 353, 359, 356, 350, 358, 357, 354, 351, 348, 351, 352, 349, 344, 348, 355, 356, 352, 355, 354, 353, 346, 351, 349, 358, 349, 354, 354, 351, 354, 355, 350, 346, 356, 356, 353, 354, 350, 353, 353, 354, 354, 354, 348, 356, 355]
ax.plot(gpu_data,'-', label='GPU-driven Pipeline', marker = '.',markersize = 8)

deferred_data = [19, 18, 19, 18, 19, 19, 19, 18, 19, 19, 16, 19, 19, 18, 19, 19, 19, 19, 19, 18, 19, 18, 19, 18, 19, 19, 18, 19, 18, 19, 19, 18, 19, 19, 19, 19, 19, 18, 19, 19, 18, 19, 19, 19, 18, 19, 18, 19, 18, 19, 18, 18, 19, 19, 18, 19, 19, 18, 19, 19]
ax.plot(deferred_data, '-', label='Deferred Pipeline', marker = '.',markersize = 8)
ax.set_ylim(bottom=0., top=400.0)

ax.legend()

plt.xlabel("time(ms)")  # add X-axis label 
plt.ylabel("frame rate(fps)")  # add Y-axis label 
#plt.fill_between(x, gpu_data, deferred_data, color='green', alpha=0.5) 
plt.grid(axis='y')
plt.show()
plt.savefig("performance-city-frustum.pdf")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
