# %%
import numpy as np
import matplotlib.pyplot as plt

# this sets up the Matplotlib interactive windows:
# %matplotlib widget

# %% [markdown]
# GPU-driven Pipeline Playground场景 普通视角

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.

x = np.arange(0, 60, 1)
gpu_data = [468, 470, 468, 474, 474, 467, 470, 468, 466, 466, 468, 473, 466, 472, 462, 469, 468, 469, 470, 468, 466, 473, 473, 470, 472, 465, 469, 465, 471, 474, 471, 467, 472, 467, 469, 467, 472, 469, 468, 472, 473, 470, 465, 470, 469, 467, 471, 467, 467, 470, 469, 467, 472, 473, 469, 475, 474, 474, 475, 468]
ax.plot(gpu_data,'-', label='GPU-driven Pipeline', marker = '.',markersize = 8)

deferred_data = [474, 462, 463, 460, 457, 457, 459, 462, 459, 463, 456, 455, 462, 462, 466, 463, 457, 463, 472, 474, 479, 480, 460, 450, 457, 460, 456, 459, 460, 461, 455, 460, 460, 455, 459, 457, 457, 458, 460, 456, 458, 460, 458, 462, 458, 463, 459, 458, 461, 456, 459, 457, 460, 456, 456, 465, 462, 458, 458, 459]
ax.plot(deferred_data, '-', label='Deferred Pipeline', marker = '.',markersize = 8)
ax.set_ylim(bottom=330., top=630.0)

ax.legend()

plt.xlabel("time(ms)")  # add X-axis label 
plt.ylabel("frame rate(fps)")  # add Y-axis label 
#plt.fill_between(x, gpu_data, deferred_data, color='green', alpha=0.5) 
plt.grid(axis='y')
plt.show()
plt.savefig("performance-playground-common.pdf")

# %% [markdown]
# GPU-driven Pipeline Playground场景 遮挡视角

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.

x = np.arange(0, 60, 1)
gpu_data = [535, 539, 534, 524, 537, 530, 536, 526, 536, 536, 534, 534, 530, 534, 527, 539, 538, 528, 531, 529, 538, 543, 534, 533, 531, 539, 528, 524, 534, 532, 531, 537, 540, 540, 529, 534, 539, 536, 537, 541, 542, 543, 533, 529, 539, 535, 539, 538, 539, 540, 538, 531, 533, 540, 528, 533, 530, 529, 531, 533]
ax.plot(gpu_data,'-', label='GPU-driven Pipeline', marker = '.',markersize = 8)

deferred_data = [355, 352, 352, 350, 350, 352, 352, 354, 350, 351, 350, 353, 351, 352, 349, 351, 350, 353, 349, 347, 353, 352, 351, 352, 351, 350, 353, 353, 353, 349, 354, 353, 349, 352, 352, 352, 350, 351, 354, 351, 353, 351, 352, 350, 351, 353, 349, 353, 349, 349, 352, 350, 352, 354, 354, 353, 354, 353, 351, 351]
ax.plot(deferred_data, '-', label='Deferred Pipeline', marker = '.',markersize = 8)
ax.set_ylim(bottom=330., top=630.0)

ax.legend()

plt.xlabel("time(ms)")  # add X-axis label 
plt.ylabel("frame rate(fps)")  # add Y-axis label 
#plt.fill_between(x, gpu_data, deferred_data, color='green', alpha=0.5) 
plt.grid(axis='y')
plt.show()
plt.savefig("performance-playground-occluded.pdf")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# GPU-driven Pipeline Playground场景 视锥视角

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.

x = np.arange(0, 60, 1)
gpu_data = [592, 614, 585, 602, 607, 601, 600, 587, 604, 624, 614, 612, 613, 605, 597, 613, 619, 613, 607, 599, 599, 592, 612, 614, 592, 593, 603, 591, 608, 614, 605, 605, 599, 597, 595, 604, 594, 608, 602, 604, 594, 598, 602, 602, 594, 597, 611, 612, 610, 602, 599, 602, 602, 599, 599, 604, 594, 616, 603, 605]
ax.plot(gpu_data,'-', label='GPU-driven Pipeline', marker = '.',markersize = 8)

deferred_data = [511, 521, 514, 519, 525, 517, 520, 521, 515, 521, 523, 522, 516, 525, 523, 518, 516, 521, 522, 523, 519, 521, 520, 517, 524, 519, 515, 516, 518, 516, 518, 521, 522, 519, 524, 516, 517, 522, 527, 521, 522, 527, 515, 519, 521, 526, 516, 523, 517, 519, 516, 520, 517, 518, 521, 517, 517, 521, 519, 521]
ax.plot(deferred_data, '-', label='Deferred Pipeline', marker = '.',markersize = 8)
ax.set_ylim(bottom=330., top=630.0)

ax.legend()

plt.xlabel("time(ms)")  # add X-axis label 
plt.ylabel("frame rate(fps)")  # add Y-axis label 
#plt.fill_between(x, gpu_data, deferred_data, color='green', alpha=0.5) 
plt.grid(axis='y')
plt.show()
plt.savefig("performance-playground-frustum.pdf")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
